# %%
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 3.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import cv2

# %%
# Read Images

# %%
img = cv2.imread('/Users/drishtant/Desktop/Machine Learning Essentials/BlackHoleDisk_desktop.png')

# %%
print(img.shape)
# Out:
# (1080, 1920, 3)

# %%
img
# Out:
# array([[[ 21,  17,  23],
#         [ 22,  18,  24],
#         [ 22,  18,  24],
#         ...,
#         [ 46, 121, 180],
#         [ 47, 123, 180],
#         [ 48, 121, 179]],
#
#        [[ 22,  18,  24],
#         [ 22,  18,  24],
#         [ 22,  18,  24],
#         ...,
#         [ 45, 121, 180],
#         [ 46, 123, 180],
#         [ 46, 120, 180]],
#
#        [[ 22,  18,  24],
#         [ 22,  18,  24],
#         [ 22,  18,  24],
#         ...,
#         [ 46, 124, 182],
#         [ 46, 124, 182],
#         [ 45, 119, 181]],
#
#        ...,
#
#        [[  6,   7,  11],
#         [  7,   8,  12],
#         [  8,   9,  13],
#         ...,
#         [ 10,  20,  27],
#         [  9,  19,  26],
#         [  9,  19,  26]],
#
#        [[  7,   8,  12],
#         [  6,   7,  11],
#         [  6,   7,  11],
#         ...,
#         [ 10,  20,  27],
#         [ 11,  21,  28],
#         [ 11,  21,  28]],
#
#        [[  9,  10,  14],
#         [  8,   9,  13],
#         [  7,   8,  12],
# ...

# %%
print(img[0][0])
# Out:
# [21 17 23]

# %%
# R G B

# %%
# Show this image - For inline use matplotlib
plt.imshow(img) # this is in BGR that's why color difference
plt.show()

# %%
newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(newImg)
plt.axis("off")
plt.show()
